# %% [markdown]
# 1. Have you worked with corrupted records?
# 2. when do you say that its corrupted records?
# 3. what happen when we encounter with corrupted records in different read mode?
# 4. How can we print bad records?
# 5. where do you store bad records and how to access later?

# %%
df = spark.read.format("csv")\
                .option("header", True)\
                .option("inferSchema",True)\
                .option("mode","PERMISSIVE")\
                .load("dbfs:/Volumes/workspace/default/pyspark-project-files/handling_corrupted_data.csv")
df.show()

# %%
df = spark.read.format("csv")\
                .option("header", True)\
                .option("inferSchema",True)\
                .option("mode","FAILFAST")\
                .load("dbfs:/Volumes/workspace/default/pyspark-project-files/handling_corrupted_data.csv")
df.show()

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("salary", IntegerType(), True),
    StructField("address", StringType(), True),
    StructField("nominee", StringType(), True),
    StructField("_corrupted_Type", StringType(), True)
])

# %%
df = spark.read.format("csv")\
                .option("header", True)\
                .option("inferschema", True)\
                .option("badRecordsPath","dbfs:/Volumes/workspace/default/pyspark-project-files/bad_records")\
                .load("dbfs:/Volumes/workspace/default/pyspark-project-files/handling_corrupted_data.csv")
df.show(truncate = False)

# %%
# %fs
ls dbfs:/Volumes/workspace/default/pyspark-project-files/bad_records/20250629T134351/bad_records

# %%
bad_data_df = spark.read.format("csv").load("dbfs:/Volumes/workspace/default/pyspark-project-files/bad_records/20250629T134351/bad_records")
bad_data_df.show()
